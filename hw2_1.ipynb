# %%
from sklearn.cluster import KMeans
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
diabetes=datasets.load_diabetes()

# %%
X_p=diabetes.data[:,2]
Y=diabetes.target
X=[X_p,Y]
plt.scatter(X[0],Y)
plt.xlabel('blood pressure')
plt.ylabel('diabetes')
# Out:
# Text(0, 0.5, 'diabetes')

# %%
kmeans = KMeans(n_clusters = 3)
data = np.transpose(X)
kmeans.fit(data)
kmeans.labels = kmeans.predict(data)
plt.scatter(X[0],X[1],c=kmeans.labels)
plt.xlabel('blood pressure')
plt.ylabel('diabetes')
plt.show()

# %%
# Elbow Method 
# inertia의 수가 완만하게 감소하게 되는 곳이 최적의 cluster 군집 수를 나타냄을 이용함

# %%
kmeans.inertia_
# Out:
# 296608.4039764498

# %%
kiner = {}
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data)
    kiner[k] = kmeans.inertia_

# %%
plt.plot(list(kiner.keys()), list(kiner.values()))

# %%
#innertia가 6인 곳부터 비교적 완만하게 감소하므로 sklearn의 최적 군집 수는 6개이다.
#이를 통해 최적의 군집 수로 다시 clustering 해보면 아래와 같다.

# %%
from sklearn.cluster import KMeans
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
diabetes=datasets.load_diabetes()

# %%
X_p=diabetes.data[:,2]
Y=diabetes.target
X=[X_p,Y]
plt.scatter(X[0],Y)
plt.xlabel('blood pressure')
plt.ylabel('diabetes')
# Out:
# Text(0, 0.5, 'diabetes')

# %%
kmeans = KMeans(n_clusters = 6)
data = np.transpose(X)
kmeans.fit(data)
kmeans.labels = kmeans.predict(data)
plt.scatter(X[0],X[1],c=kmeans.labels)
plt.xlabel('blood pressure')
plt.ylabel('diabetes')
plt.show()
